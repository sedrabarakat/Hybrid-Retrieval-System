# %%
# !pip install faiss
# Out:
# ERROR: Could not find a version that satisfies the requirement faiss (from versions: none)
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for faiss

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Barakat\Lectures\IR\torchenv\Scripts\python.exe

# %%
# !c:/Users/Barakat/Lectures/IR/torchenv/Scripts/python.exe -m pip install torch
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m ipykernel install --user --name=torchenv --display-name "Python (torchenv)"
# Out:
# Installed kernelspec torchenv in C:\Users\Barakat\AppData\Roaming\jupyter\kernels\torchenv

# %%
import torch
print(torch.__version__)
# Out:
# c:\Users\Barakat\Lectures\IR\torchenv\Lib\site-packages\torch\_subclasses\functional_tensor.py:276: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:81.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# 2.7.1+cpu
