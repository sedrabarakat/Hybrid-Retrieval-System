# %%
import nltk
nltk.data.path.append('./nltk_data')

# %%
# %pip install ir_datasets

# %%
import ir_datasets

dataset = ir_datasets.load("antique/train")

# حساب عدد الوثائق
try:
    count = dataset.docs_count()
except AttributeError:
    count = sum(1 for _ in dataset.docs_iter())

print(f"عدد الوثائق: {count}")

# عرض أول 3 وثائق
for i, doc in enumerate(dataset.docs_iter()):
    print(f"Document {i+1}")
    print("Document ID:", doc.doc_id)
    print("Text:", doc.text)
    print("=" * 50)
    if i == 2:  # بعد 3 وثائق (i = 0,1,2)
        break
# Out:
# عدد الوثائق: 403666
# Document 1
# Document ID: 2020338_0
# Text: A small group of politicians believed strongly that the fact that Saddam Hussien remained in power after the first Gulf War was a signal of weakness to the rest of the world, one that invited attacks and terrorism. Shortly after taking power with George Bush in 2000 and after the attack on 9/11, they were able to use the terrorist attacks to justify war with Iraq on this basis and exaggerated threats of the development of weapons of mass destruction. The military strength of the U.S. and the brutality of Saddam's regime led them to imagine that the military and political victory would be relatively easy.
# ...
# Document 2
# Document ID: 2020338_1
# Text: Because there is a lot of oil in Iraq.
# ...
# Document 3
# Document ID: 2020338_2
# ...

# %%
from corpus import get_corpus

get_corpus("antique")
# Out:
# {'2020338_0': "A small group of politicians believed strongly that the fact that Saddam Hussien remained in power after the first Gulf War was a signal of weakness to the rest of the world, one that invited attacks and terrorism. Shortly after taking power with George Bush in 2000 and after the attack on 9/11, they were able to use the terrorist attacks to justify war with Iraq on this basis and exaggerated threats of the development of weapons of mass destruction. The military strength of the U.S. and the brutality of Saddam's regime led them to imagine that the military and political victory would be relatively easy.",
#  '2020338_1': 'Because there is a lot of oil in Iraq.',
# ...

# %%
from corpus import get_corpus

docs = get_corpus("beir")
print(f"عدد الوثائق: {len(docs)}")

# عرض أول 3 وثائق
for i, (doc_id, text) in enumerate(docs.items()):
    print(f"Document {i+1}")
    print("Document ID:", doc_id)
    print("Text:", text)
    print("=" * 50)
    if i == 2:  # بعد 3 وثائق
        break
# Out:
# عدد الوثائق: 382545
# Document 1
# Document ID: c67482ba-2019-04-18T13:32:05Z-00000-000
# Text: My opponent forfeited every round. None of my arguments were answered. I don’t like the idea of winning by default, but here we are.Tule: it’s good for students to get involved and address big issues like teen pregnancy. You need to be able to answer arguments like mine and not simply prepare for an abstinence-only type of response. You should also be aware that, in the U.S., condoms may be sold to minors in ANY state. A retailer who says it is illegal to sell you them is, frankly, wrong.
# ...
# Document 2
# Document ID: c67482ba-2019-04-18T13:32:05Z-00001-000
# ...

# %%
from corpus import get_corpus

# تحميل كويرات BEIR
beir_queries = get_corpus("beir-queries")
print(f"عدد الكويرات في BEIR: {len(beir_queries)}")

# تحميل كويرات ANTIQUE
antique_queries = get_corpus("antique-queries")
print(f"عدد الكويرات في ANTIQUE: {len(antique_queries)}")

# عرض أول 3 كويرات BEIR كمثال
for i, (query_id, text) in enumerate(beir_queries.items()):
    print(f"Query {i+1}")
    print("Query ID:", query_id)
    print("Text:", text)
    print("="*50)
    if i == 2:
        break
# Out:
# عدد الكويرات في BEIR: 49
# عدد الكويرات في ANTIQUE: 2426
# Query 1
# Query ID: 1
# Text: Should teachers get tenure?
# ...
# Query 2
# Query ID: 2
# Text: Is vaping with e-cigarettes safe?
# ...
# Query 3
# Query ID: 3
# Text: Should insider trading be allowed?
# ...

# %%
# %pip install pyspellchecker

# %%
# %pip install pyspellchecker
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pyspellchecker-0.8.3-py3-none-any.whl.metadata (9.5 kB)
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
# ...

# %%
# %pip install mysql-connector-python

# %%
# %pip install pycountry
