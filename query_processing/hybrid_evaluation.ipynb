# %%
from evaluation import evaluation_calc

dataset_name = "antique"

evaluation_calc(
    dataset_name,
    top_k=10,
    similarity_threshold=0.3,  
    method="hybrid",
)
# Out:
# tfidf_matrix.shape: (403666, 256095)
# embeddings.shape: (403666, 768)
# ✅ hybrid_vectors created: (403666, 256863)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 from evaluation import evaluation_calc
#       3 dataset_name = "antique"
# ----> 5 evaluation_calc(
#       6     dataset_name,
#       7     top_k=10,
#       8     similarity_threshold=0.3,
#       9     method="hybrid",
#      10 )
#
# File c:\Users\Barakat\Lectures\IR\query_processing\evaluation.py:85, in evaluation_calc(dataset_name, top_k, similarity_threshold, method)
#      82 qrels_corpus = get_qrels_from_file(dataset_name=dataset_name)
#      83 ground_truth = build_ground_truth(queries_corpus, qrels_corpus)
# ---> 85 search_results = get_all_quires_result(
#      86     queries_corpus=queries_corpus,
#      87     dataset_name=dataset_name,
#      88     method=method,
# ...
