# %%
from ranking_clustring import match_and_rank

query = "What is also?"
dataset = "beir"

results = match_and_rank(query, dataset)
print("Top ranked docs:", list(results.items())[:5])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ranking_clustring import match_and_rank
#       3 query = "What is also?"
#       4 dataset = "beir"
#
# File c:\Users\HP\IR-project\query_processing\with_clustring\ranking_clustring.py:20
#      18 from storage.vector_storage import load_tfidf_matrix, load_doc_ids, load_clusters
#      19 from indexing.inverted_index_loader import load_inverted_index
# ---> 20 from tf.query_processing import QueryProcessor
#      22 import mysql.connector
#      24 # الحل لمشكلة 'No module named 'TF_IDF''
#
# ModuleNotFoundError: No module named 'tf'
