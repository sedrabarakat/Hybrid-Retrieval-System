# %%
from TF_IDF import build_save_vectorizer
build_save_vectorizer("beir")
# Out:
# Building TF-IDF model for beir
# Fetched batch 1 (1000 documents)
# Processing 10 documents
# Successfully saved TF-IDF model for beir

# %%
import nltk

# Download all required packages
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Eng Islam\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
import sys
sys.path.append("F:\\IR\\IR")  # Add the root folder to Python path

from vectorize.embedding import generate_embedding
generate_embedding("beir")
# Out:
# Starting embedding generation for dataset: beir
# Fetching batch starting at document 0
# Processed batch 1 - 1000 documents
# Fetching batch starting at document 1000
# Total documents loaded: 1000
# Generating embeddings...
# Saving embeddings...
# Successfully saved embeddings for dataset: beir_all

# %%
from TF_IDF import build_save_vectorizer
build_save_vectorizer("beir")
# Out:
# [nltk_data] Error loading punkt: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# [nltk_data] Error loading wordnet: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# [nltk_data] Error loading omw-1.4: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# ...

# %%
from scipy.sparse import load_npz
m = load_npz('saved_models/tfidf/beir_all_tfidf.npz')
print(m.shape)
# Out:
# (382545, 711463)

# %%
from hybrid import generate_hybrid
generate_hybrid("beir")
# Out:
# Starting hybrid vector generation...
# ❌ Failed to download/load TF-IDF matrix: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
