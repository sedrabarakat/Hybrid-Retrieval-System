# %%
from inverted_index import build_inverted_index

build_inverted_index("beir")
build_inverted_index("antique")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from inverted_index import build_inverted_index
# ----> 3 build_inverted_index("beir")
#       4 build_inverted_index("antique")
#
# File c:\Users\HP\IR-project\indexing\inverted_index.py:34, in build_inverted_index(dataset_name)
#      31     print(f"[!] الوثيقة {doc_id} تم تجاوزها (النص الأصلي فارغ).")
#      32     continue
# ---> 34 terms = get_preprocessed_text_terms(raw_text, dataset_name)
#      36 if not terms:
#      37     print(f"[!] الوثيقة {doc_id} تم تجاوزها (لا توجد كلمات بعد المعالجة).")
#
# File c:\Users\HP\IR-project\text_processing\text_preprocessing.py:110, in get_preprocessed_text_terms(text, dataset_name)
#     107 tokens = _lemmatize_tokens(tokens)
#     109 # Use spaCy for named entity extraction only
# --> 110 doc = nlp(text)
# ...

# %% [markdown]
# import os
# import sys
# import joblib
#
# project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
# if project_root not in sys.path:
#     sys.path.insert(0, project_root)
#
# index_path = r"C:\Users\HP\IR-project\indexing\saved_models\inverted_index\beir_inverted_index.joblib"
#
# if not os.path.exists(index_path):
#     raise FileNotFoundError(f"لم يتم العثور على الفهرس المعكوس: {index_path}")
#
# inverted_index = joblib.load(index_path)
#
# print(f"عدد المصطلحات في الفهرس: {len(inverted_index)}")
#
# # جمع جميع أنواع الـ id من أول 1000 مصطلح (أو أقل إذا الفهرس أصغر)
# id_types = set()
# sample_count = 0
# max_terms_to_check = 1000
#
# for term, doc_ids in inverted_index.items():
#     for doc_id in doc_ids:
#         id_types.add(type(doc_id))
#     sample_count += 1
#     if sample_count >= max_terms_to_check:
#         break
#
# print(f"أنواع الـ id المستخدمة في الفهرس (من عينة حتى {max_terms_to_check} مصطلح):")
# for t in id_types:
#     print(f"- {t}")

# %%
import os
import sys
import joblib

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

index_path = r"C:\Users\HP\IR-project\indexing\saved_models\inverted_index\beir_inverted_index.joblib"

if not os.path.exists(index_path):
    raise FileNotFoundError(f"لم يتم العثور على الفهرس المعكوس: {index_path}")

inverted_index = joblib.load(index_path)

print(f"عدد المصطلحات في الفهرس: {len(inverted_index)}")

# جمع جميع أنواع الـ id من أول 1000 مصطلح (أو أقل إذا الفهرس أصغر)
id_types = set()
sample_count = 0
max_terms_to_check = 1000

for term, doc_ids in inverted_index.items():
    for doc_id in doc_ids:
        id_types.add(type(doc_id))
    sample_count += 1
    if sample_count >= max_terms_to_check:
        break

print(f"أنواع الـ id المستخدمة في الفهرس (من عينة حتى {max_terms_to_check} مصطلح):")
for t in id_types:
    print(f"- {t}")
# Out:
# عدد المصطلحات في الفهرس: 43
# أنواع الـ id المستخدمة في الفهرس (من عينة حتى 1000 مصطلح):
# - <class 'int'>

# %%
import os
import joblib

index_path = r"C:\Users\HP\IR-project\indexing\saved_models\inverted_index\beir_inverted_index.joblib"

# تحميل الفهرس المعكوس
inverted_index = joblib.load(index_path)

# طباعة عدد المصطلحات في الفهرس
print(f"عدد المصطلحات في الفهرس: {len(inverted_index)}\n")

# طباعة محتويات الفهرس (مصطلح مع قائمة الوثائق المرتبطة به)
# هنا نطبع أول 10 مصطلحات فقط لتجنب الطباعة الكثيرة جداً
for i, (term, doc_ids) in enumerate(inverted_index.items()):
    print(f"مصطلح [{i+1}]: '{term}' مرتبط بالوثائق: {doc_ids}")
    if i >= 9:
        break
# Out:
# عدد المصطلحات في الفهرس: 43
#
# مصطلح [1]: 'also' مرتبط بالوثائق: [527629]
# مصطلح [2]: 'default' مرتبط بالوثائق: [527629]
# مصطلح [3]: 'abl' مرتبط بالوثائق: [527629]
# مصطلح [4]: 'minor' مرتبط بالوثائق: [527629]
# مصطلح [5]: 'everi' مرتبط بالوثائق: [527629]
# مصطلح [6]: 'may' مرتبط بالوثائق: [527629]
# مصطلح [7]: 'involv' مرتبط بالوثائق: [527629]
# مصطلح [8]: 'teen' مرتبط بالوثائق: [527629]
# مصطلح [9]: 'u' مرتبط بالوثائق: [527629]
# مصطلح [10]: 'need' مرتبط بالوثائق: [527629]

# %%
import joblib

index = joblib.load("C:/Users/HP/IR-project/indexing/saved_models/inverted_index/beir_inverted_index.joblib")
print(index["freedom"])  # مثلاً كل المستندات اللي فيها كلمة "freedom"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 4
#       1 import joblib
#       3 index = joblib.load("C:/Users/HP/IR-project/indexing/saved_models/inverted_index/beir_inverted_index.joblib")
# ----> 4 print(index["freedom"])
#
# KeyError: 'freedom'

# %%
import joblib

index_path = "C:/Users/HP/IR-project/indexing/saved_models/inverted_index/antique_inverted_index.joblib"
inverted_index = joblib.load(index_path)
print("عدد الكلمات في الفهرس:", len(inverted_index))
print("بعض الكلمات:", list(inverted_index.keys())[:10])
# Out:
# عدد الكلمات في الفهرس: 142137
# بعض الكلمات: ['hussien', 'regim', 'one', 'weapon', 'abl', 'iraq', 'remain', 'signal', 'exagger', '9']
