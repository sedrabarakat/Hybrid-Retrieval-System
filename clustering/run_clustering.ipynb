# %%
import sys
import os

# اجعل الجذر للمشروع ضمن sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from clustering import plot_elbow_curve, build_and_view_clusters
plot_elbow_curve("antique", max_k=20)
# Out:
# Generating Elbow Curve for antique using MiniBatchKMeans...
# Attempting to load TF-IDF matrix from: c:\Users\HP\IR-project\vectorize\saved_models\tfidf\antique_all_tfidf.npz
# TF-IDF matrix loaded in 0.64 seconds. Matrix shape: (403666, 204284)
# Calculating WCSS for k = 2 using MiniBatchKMeans...
# MiniBatchKMeans for k=2 completed in 0.48 seconds.
# Calculating WCSS for k = 3 using MiniBatchKMeans...
# MiniBatchKMeans for k=3 completed in 5.98 seconds.
# Calculating WCSS for k = 4 using MiniBatchKMeans...
# MiniBatchKMeans for k=4 completed in 3.67 seconds.
# Calculating WCSS for k = 5 using MiniBatchKMeans...
# MiniBatchKMeans for k=5 completed in 13.10 seconds.
# Calculating WCSS for k = 6 using MiniBatchKMeans...
# MiniBatchKMeans for k=6 completed in 15.57 seconds.
# Calculating WCSS for k = 7 using MiniBatchKMeans...
# MiniBatchKMeans for k=7 completed in 17.21 seconds.
# Calculating WCSS for k = 8 using MiniBatchKMeans...
# ...

# %%
import sys
import os

# اجعل الجذر للمشروع ضمن sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from clustering import plot_elbow_curve, build_and_view_clusters
plot_elbow_curve("antique", max_k=10)
# Out:
# Generating Elbow Curve for antique using MiniBatchKMeans...
# TF-IDF matrix loaded in 0.50 seconds.
# Calculating WCSS for k = 2 using MiniBatchKMeans...
# KMeans for k=2 completed in 1.56 seconds.
# Calculating WCSS for k = 3 using MiniBatchKMeans...
# KMeans for k=3 completed in 0.45 seconds.
# Calculating WCSS for k = 4 using MiniBatchKMeans...
# KMeans for k=4 completed in 8.55 seconds.
# Calculating WCSS for k = 5 using MiniBatchKMeans...
# KMeans for k=5 completed in 10.13 seconds.
# Calculating WCSS for k = 6 using MiniBatchKMeans...
# KMeans for k=6 completed in 14.06 seconds.
# Calculating WCSS for k = 7 using MiniBatchKMeans...
# KMeans for k=7 completed in 21.43 seconds.
# Calculating WCSS for k = 8 using MiniBatchKMeans...
# KMeans for k=8 completed in 0.89 seconds.
# Calculating WCSS for k = 9 using MiniBatchKMeans...
# KMeans for k=9 completed in 24.73 seconds.
# Calculating WCSS for k = 10 using MiniBatchKMeans...
# KMeans for k=10 completed in 30.40 seconds.
# ...

# %%
import sys
import os

# اجعل الجذر للمشروع ضمن sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from clustering import plot_elbow_curve, build_and_view_clusters
build_and_view_clusters("antique", n_clusters=7, top_terms=True)
# Out:
# Clustering antique into 7 clusters using MiniBatchKMeans...
# Loading TF-IDF matrix...
# Attempting to load TF-IDF matrix from: c:\Users\HP\IR-project\vectorize\saved_models\tfidf\antique_all_tfidf.npz
# TF-IDF matrix loaded in 0.80 seconds. Matrix shape: (403666, 204284)
# Starting MiniBatchKMeans training for 7 clusters...
# MiniBatchKMeans training and prediction completed in 18.19 seconds.
# Calculating Silhouette Score (this might take a very long time for large datasets)...
# Sampling 50000 documents for Silhouette Score calculation...
# Silhouette Score (sampled) for antique: 0.0031
# Silhouette Score calculation completed in 81.08 seconds.
# Counting documents per cluster...
# Cluster 0 has 274663 vectors
# Cluster 1 has 40261 vectors
# Cluster 2 has 11049 vectors
# Cluster 3 has 11289 vectors
# Cluster 4 has 47347 vectors
# Cluster 5 has 13412 vectors
# Cluster 6 has 5645 vectors
# Document counts per cluster displayed.
# Performing TruncatedSVD for 2D visualization...
# ...

# %%
import sys
import os

# اجعل الجذر للمشروع ضمن sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from clustering import plot_elbow_curve, build_and_view_clusters
build_and_view_clusters("antique", n_clusters=9, top_terms=True)
# Out:
# Clustering antique into 9 clusters using MiniBatchKMeans...
# Loading TF-IDF matrix...
# Attempting to load TF-IDF matrix from: c:\Users\HP\IR-project\vectorize\saved_models\tfidf\antique_all_tfidf.npz
# TF-IDF matrix loaded in 0.58 seconds. Matrix shape: (403666, 204284)
# Starting MiniBatchKMeans training for 9 clusters...
# MiniBatchKMeans training and prediction completed in 25.10 seconds.
# Calculating Silhouette Score (this might take a very long time for large datasets)...
# Sampling 50000 documents for Silhouette Score calculation...
# Silhouette Score (sampled) for antique: 0.0001
# Silhouette Score calculation completed in 83.04 seconds.
# Counting documents per cluster...
# Cluster 0 has 9 vectors
# Cluster 1 has 1 vectors
# Cluster 2 has 3 vectors
# Cluster 3 has 71640 vectors
# Cluster 4 has 295364 vectors
# Cluster 5 has 17159 vectors
# Cluster 6 has 16 vectors
# Cluster 7 has 7812 vectors
# Cluster 8 has 11662 vectors
# Document counts per cluster displayed.
# ...

# %%
import sys
import os

# اجعل الجذر للمشروع ضمن sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from clustering import plot_elbow_curve, build_and_view_clusters
plot_elbow_curve(dataset_name='beir', max_k=20)
# Out:
# Generating Elbow Curve for beir using MiniBatchKMeans...
# Calculating WCSS for k = 2 using MiniBatchKMeans...
# Calculating WCSS for k = 3 using MiniBatchKMeans...
# Calculating WCSS for k = 4 using MiniBatchKMeans...
# Calculating WCSS for k = 5 using MiniBatchKMeans...
# Calculating WCSS for k = 6 using MiniBatchKMeans...
# Calculating WCSS for k = 7 using MiniBatchKMeans...
# Calculating WCSS for k = 8 using MiniBatchKMeans...
# Calculating WCSS for k = 9 using MiniBatchKMeans...
# Calculating WCSS for k = 10 using MiniBatchKMeans...
# Calculating WCSS for k = 11 using MiniBatchKMeans...
# Calculating WCSS for k = 12 using MiniBatchKMeans...
# Calculating WCSS for k = 13 using MiniBatchKMeans...
# Calculating WCSS for k = 14 using MiniBatchKMeans...
# Calculating WCSS for k = 15 using MiniBatchKMeans...
# Calculating WCSS for k = 16 using MiniBatchKMeans...
# Calculating WCSS for k = 17 using MiniBatchKMeans...
# Calculating WCSS for k = 18 using MiniBatchKMeans...
# ...

# %%
import sys
import os

# اجعل الجذر للمشروع ضمن sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from clustering import plot_elbow_curve, build_and_view_clusters
plot_elbow_curve("beir", max_k=20)
# Out:
# Generating Elbow Curve for beir using MiniBatchKMeans...
# Attempting to load TF-IDF matrix from: c:\Users\HP\IR-project\vectorize\saved_models\tfidf\beir_all_tfidf.npz
# TF-IDF matrix loaded in 4.11 seconds. Matrix shape: (382545, 711463)
# Calculating WCSS for k = 2 using MiniBatchKMeans...
# MiniBatchKMeans for k=2 completed in 1.20 seconds.
# Calculating WCSS for k = 3 using MiniBatchKMeans...
# MiniBatchKMeans for k=3 completed in 1.08 seconds.
# Calculating WCSS for k = 4 using MiniBatchKMeans...
# MiniBatchKMeans for k=4 completed in 20.52 seconds.
# Calculating WCSS for k = 5 using MiniBatchKMeans...
# MiniBatchKMeans for k=5 completed in 34.77 seconds.
# Calculating WCSS for k = 6 using MiniBatchKMeans...
# MiniBatchKMeans for k=6 completed in 50.48 seconds.
# Calculating WCSS for k = 7 using MiniBatchKMeans...
# MiniBatchKMeans for k=7 completed in 2.35 seconds.
# Calculating WCSS for k = 8 using MiniBatchKMeans...
# MiniBatchKMeans for k=8 completed in 53.38 seconds.
# ...

# %%
import sys
import os

# اجعل الجذر للمشروع ضمن sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from clustering import plot_elbow_curve, build_and_view_clusters
build_and_view_clusters("beir", n_clusters=12, top_terms=True)
# Out:
# Clustering beir into 12 clusters using MiniBatchKMeans...
# Loading TF-IDF matrix...
# Attempting to load TF-IDF matrix from: c:\Users\HP\IR-project\vectorize\saved_models\tfidf\beir_all_tfidf.npz
# TF-IDF matrix loaded in 4.05 seconds. Matrix shape: (382545, 711463)
# Starting MiniBatchKMeans training for 12 clusters...
# MiniBatchKMeans training and prediction completed in 79.50 seconds.
# Calculating Silhouette Score (this might take a very long time for large datasets)...
# Sampling 50000 documents for Silhouette Score calculation...
# Silhouette Score (sampled) for beir: 0.0133
# Silhouette Score calculation completed in 199.06 seconds.
# Counting documents per cluster...
# Cluster 0 has 89057 vectors
# Cluster 1 has 38773 vectors
# Cluster 2 has 3679 vectors
# Cluster 3 has 192183 vectors
# Cluster 4 has 2231 vectors
# Cluster 5 has 25864 vectors
# Cluster 6 has 3465 vectors
# Cluster 7 has 9796 vectors
# Cluster 8 has 7099 vectors
# Cluster 9 has 5474 vectors
# ...

# %%
import sys
import os

# اجعل الجذر للمشروع ضمن sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from clustering import plot_elbow_curve, build_and_view_clusters
build_and_view_clusters("beir", n_clusters=18, top_terms=True)
# Out:
# Clustering beir into 18 clusters using MiniBatchKMeans...
# Loading TF-IDF matrix...
# Attempting to load TF-IDF matrix from: c:\Users\HP\IR-project\vectorize\saved_models\tfidf\beir_all_tfidf.npz
# TF-IDF matrix loaded in 5.04 seconds. Matrix shape: (382545, 711463)
# Starting MiniBatchKMeans training for 18 clusters...
# MiniBatchKMeans training and prediction completed in 176.68 seconds.
# Calculating Silhouette Score (this might take a very long time for large datasets)...
# Sampling 50000 documents for Silhouette Score calculation...
# Silhouette Score (sampled) for beir: 0.0106
# Silhouette Score calculation completed in 240.76 seconds.
# Counting documents per cluster...
# Cluster 0 has 2 vectors
# Cluster 1 has 29 vectors
# Cluster 2 has 14 vectors
# Cluster 3 has 31196 vectors
# Cluster 4 has 25727 vectors
# Cluster 5 has 38673 vectors
# Cluster 6 has 4909 vectors
# Cluster 7 has 6146 vectors
# Cluster 8 has 2 vectors
# Cluster 9 has 4063 vectors
# ...

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from clustering import plot_elbow_curve, build_and_view_clusters
build_and_view_clusters("beir", n_clusters=12, top_terms=True)
# Out:
# Clustering beir into 12 clusters using MiniBatchKMeans...
# Loading TF-IDF matrix...
# Attempting to load TF-IDF matrix from: c:\Users\HP\IR-project\vectorize\saved_models\tfidf\beir_all_tfidf.npz
# TF-IDF matrix loaded in 3.83 seconds. Matrix shape: (382545, 711463)
# Starting MiniBatchKMeans training for 12 clusters...
# MiniBatchKMeans training and prediction completed in 75.09 seconds.
# Calculating Silhouette Score (this might take a very long time for large datasets)...
# Sampling 50000 documents for Silhouette Score calculation...
# Silhouette Score (sampled) for beir: 0.0126
# Silhouette Score calculation completed in 199.87 seconds.
# Counting documents per cluster...
# Cluster 0 has 89057 vectors
# Cluster 1 has 38773 vectors
# Cluster 2 has 3679 vectors
# Cluster 3 has 192183 vectors
# Cluster 4 has 2231 vectors
# Cluster 5 has 25864 vectors
# Cluster 6 has 3465 vectors
# Cluster 7 has 9796 vectors
# Cluster 8 has 7099 vectors
# Cluster 9 has 5474 vectors
# ...

# %%
import sys
import os

# اجعل الجذر للمشروع ضمن sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from clustering import plot_elbow_curve, build_and_view_clusters
build_and_view_clusters("beir", n_clusters=18, top_terms=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 9
#       6 if project_root not in sys.path:
#       7     sys.path.insert(0, project_root)
# ----> 9 from clustering import plot_elbow_curve, build_and_view_clusters
#      10 build_and_view_clusters("beir", n_clusters=18, top_terms=True)
#
# File c:\Users\HP\IR-project\clustering\clustering.py:185
#     181 import vectorize.tokenizer_definition
#     183 sys.modules["TF_IDF"] = vectorize.tokenizer_definition
# --> 185 from storage.vector_storage import load_tfidf_matrix, load_vectorizer, save_clusters
#     188 # -------------------------------------------------------------------------------------
#     189 # Elbow Curve
#     190 # -------------------------------------------------------------------------------------
#     192 def plot_elbow_curve(dataset_name: str, max_k=30):
#
# ...
